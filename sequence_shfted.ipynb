# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer, TransformerDecoder, TransformerDecoderLayer
import pandas as pd
import numpy as np

# %%
def create_data_sequence(X_data, Y_data, lookback):
    """
    Creates input-output sequences from raw data arrays based on the lookback period for one-step-ahead prediction.

    :param X_data: Array of input data (features).
    :param Y_data: Array of output data (targets).
    :param lookback: The lookback window for creating sequences.
    :return: Sequences of inputs and outputs, with outputs shifted by one timestep.
    """
    X_sequences, y_sequences = [], []
    for i in range(lookback, len(X_data) - 1):  # Stop one step early for shifting
        X_sequences.append(X_data[i - lookback:i])
        y_sequences.append(Y_data[i - lookback + 1:i + 1])  # Shift Y by one timestep

    return np.array(X_sequences), np.array(y_sequences)

# %%
#load data for training and testing
import pandas as pd
import numpy as np
train_df = pd.read_csv("Combined_Training31-Aug-2023.csv")
test_df = pd.read_csv("Combined_Testing31-Aug-2023.csv")
X_data_train = train_df[['SOC', 'Current', 'Temp']].values
y_data_train =  train_df['Voltage'].values
X_sequences_train, y_sequences_train = create_data_sequence(X_data_train, y_data_train, 400)

# %%
X_sequences_train.shape, y_sequences_train.shape
# Out:
# ((761801, 400, 3), (761801, 400))

# %%
X_tensor = torch.tensor(X_sequences_train, dtype=torch.float32)
y_tensor = torch.tensor(y_sequences_train, dtype=torch.float32)

# %%
torch.save(X_tensor, 'X_tensor.pt')
torch.save(y_tensor, 'y_tensor.pt')

# %%
X_tensor = torch.load('X_tensor.pt')
y_tensor = torch.load('y_tensor.pt')
# Out:
# /tmp/ipykernel_2145322/4217068139.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   X_tensor = torch.load('X_tensor.pt')
# /tmp/ipykernel_2145322/4217068139.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   y_tensor = torch.load('y_tensor.pt')

# %%
from torch.utils.data import DataLoader, TensorDataset, SubsetRandomSampler

# Define parameters
batch_size = 64
train_split = 0.7
seed = 42  # for reproducibility

# Create a TensorDataset
dataset = TensorDataset(X_tensor, y_tensor)
dataset_size = len(dataset)
indices = list(range(dataset_size))

# Calculate train and validation sizes
train_size = int(dataset_size * train_split)
valid_size = dataset_size - train_size

# Shuffle the indices
np.random.seed(seed)
np.random.shuffle(indices)

# Split indices into training and validation sets
train_indices, valid_indices = indices[:train_size], indices[train_size:]

# Create samplers for training and validation
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(valid_indices)

# Create DataLoaders with samplers
train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, drop_last=True)
val_loader = DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler, drop_last=True)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer, TransformerDecoder, TransformerDecoderLayer

class TransformerModel(nn.Module):
    def __init__(self, input_size=3, output_size=1, embed_size=32, hidden_size=64, e_num_layers=1, d_num_layers=1, num_heads=4, dropout_prob=0.1, device="cpu"):
        super(TransformerModel, self).__init__()
        self.device = device

        # Embedding layer for combined input (SOC, current, temperature)
        self.embedding = nn.Linear(input_size, embed_size).to(self.device)

        # Embedding layer for decoder input (voltage)
        self.dec_embedding = nn.Linear(output_size, embed_size).to(self.device)

        # Transformer encoder for input sequence
        self.encoder = TransformerEncoder(
            TransformerEncoderLayer(
                d_model=embed_size,
                nhead=num_heads,
                dim_feedforward=hidden_size,
                dropout=dropout_prob,
                batch_first=True
            ),
            num_layers=e_num_layers
        ).to(self.device)

        # Transformer decoder for autoregressive prediction
        self.decoder = TransformerDecoder(
            TransformerDecoderLayer(
                d_model=embed_size,
                nhead=num_heads,
                dim_feedforward=hidden_size,
                dropout=dropout_prob,
                batch_first=True
            ),
            num_layers=d_num_layers
        ).to(self.device)

        # Output layer to predict voltage at each timestep
        self.output_layer = nn.Linear(embed_size, output_size).to(self.device)

    def forward(self, X, dec_input):
        """
        X: Input sequence containing (SOC, Current, Temperature), shape: (batch_size, seq_len, input_size)
        dec_input: Voltage sequence for the decoder, shape: (batch_size, seq_len, output_size)
        """
        
        # Check input shapes
        print("Shape of X before embedding:", X.shape)  # Expected: (batch_size, seq_len, input_size)
        print("Shape of dec_input before embedding:", dec_input.shape)  # Expected: (batch_size, seq_len, output_size)
        
        # Embedding the combined input
        X = self.embedding(X.to(self.device))  # Shape should be (batch_size, seq_len, embed_size)
        print("Shape of X after embedding:", X.shape)  # Expected: (batch_size, seq_len, embed_size)

        # Encoder pass
        encoder_output = self.encoder(X)  # Shape should be (batch_size, seq_len, embed_size)
        print("Shape of encoder output:", encoder_output.shape)  # Expected: (batch_size, seq_len, embed_size)

        # Embedding the decoder input
        dec_input = dec_input.unsqueeze(-1)
        dec_input = self.dec_embedding(dec_input.to(self.device))  # Shape should be (batch_size, seq_len, embed_size)
        print("Shape of dec_input after embedding:", dec_input.shape)  # Expected: (batch_size, seq_len, embed_size)

        # Create a mask for the decoder
        tgt_mask = torch.triu(torch.ones(dec_input.size(1), dec_input.size(1)), diagonal=1).bool().to(self.device)
        
        # Decoder pass
        decoder_output = self.decoder(dec_input, encoder_output, tgt_mask=tgt_mask)
        print("Shape of decoder output:", decoder_output.shape)  # Expected: (batch_size, seq_len, embed_size)

        # Output layer
        output = self.output_layer(decoder_output)  # Final shape should be (batch_size, seq_len, output_size)
        print("Shape of output after output layer:", output.shape)  # Expected: (batch_size, seq_len, output_size)

        return output
        
    def training_step(self, X, y, optimizer):
        '''Training step with teacher forcing for autoregressive prediction'''
        
        # Move data to device
        device = self.device
        X, y = X.to(device), y.to(device)
        
        # Encoder pass
        X_embedded = self.embedding(X)  # Shape: [64, 400, 16]
        encoder_output = self.encoder(X_embedded)  # Shape: [64, 400, 16]
        print("Encoder output shape:", encoder_output.shape)
        
        # Initialize the decoder input with the first actual voltage value (teacher forcing)
        dec_input = y[:, 0].unsqueeze(1).unsqueeze(-1)  # Shape: [64, 1, 1]
        print("Initial dec_input shape:", dec_input.shape)
        
        output_seq = []
        
        for t in range(y.shape[1]):
            # Embed the decoder input for the current timestep
            dec_input_embedded = self.dec_embedding(dec_input)  # Expected shape: [64, 1, 16]
            print(f"Shape after embedding at timestep {t}:", dec_input_embedded.shape)
            
            # Check dimensions
            assert dec_input_embedded.dim() == 3, f"Expected 3D tensor, got {dec_input_embedded.dim()}D"
            assert encoder_output.dim() == 3, f"Expected 3D tensor, got {encoder_output.dim()}D"
            
            # Decoder pass with cross-attention to encoder output
            decoder_output = self.decoder(dec_input_embedded, encoder_output)  # Shape: [64, 1, 16]
            
            # Predict voltage at the next timestep
            voltage_prediction = self.output_layer(decoder_output[:, -1, :])  # Shape: [64, 1]
            
            # Collect prediction
            output_seq.append(voltage_prediction)
            
            # Update decoder input for the next timestep with the actual next voltage (teacher forcing)
            if t < y.shape[1] - 1:
                dec_input = y[:, t + 1].unsqueeze(1).unsqueeze(-1)  # Shape: [64, 1, 1]
    
        # Concatenate all timestep predictions
        output_seq = torch.cat(output_seq, dim=1).unsqueeze(-1)  # Shape: [64, 400, 1]
        
        # Adjust y to match the shape of output_seq
        y = y.unsqueeze(-1)  # Shape: [64, 400, 1]
        
        # Calculate the loss over the entire predicted sequence
        loss = F.mse_loss(output_seq, y)
        
        # Backpropagation and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
        return loss.item()
    
    def validation_step(self, X, y):
        '''Validation step with autoregressive prediction'''
        
        # Move data to device
        device = self.device
        X, y = X.to(device), y.to(device)
        
        # Encoder pass
        X_embedded = self.embedding(X)  # Shape: [64, 400, 16]
        encoder_output = self.encoder(X_embedded)  # Shape: [64, 400, 16]
    
        # Initialize the decoder input (e.g., with zero or first actual voltage)
        dec_input = y[:, 0].unsqueeze(1)  # Shape: [64, 1]
    
        output_seq = []
    
        for t in range(y.shape[1]):
            # Embed the decoder input for the current timestep
            dec_input_embedded = self.dec_embedding(dec_input)  # Shape: [64, 1, 16]
    
            # Decoder pass with cross-attention to encoder output
            decoder_output = self.decoder(dec_input_embedded, encoder_output)  # Shape: [64, 1, 16]
    
            # Predict voltage at the next timestep
            voltage_prediction = self.output_layer(decoder_output[:, -1, :])  # Shape: [64, 1]
    
            # Collect prediction
            output_seq.append(voltage_prediction)
    
            # Update decoder input for the next timestep with the model's own prediction
            dec_input = voltage_prediction  # Autoregressive: use prediction as next input
    
        # Concatenate all timestep predictions
        output_seq = torch.cat(output_seq, dim=1)  # Shape: [64, 400]
        
        # Calculate the loss over the entire predicted sequence
        loss = F.mse_loss(output_seq, y)
        
        return loss.item()

# %%
def build_transformer(input_size=3, embed_size=32, hidden_size=64, e_num_layers=1, d_num_layers=1, num_heads=4, dropout_prob=0.1, device="cpu"):
    return TransformerModel(
        input_size=input_size,
        embed_size=embed_size,
        hidden_size=hidden_size,
        e_num_layers=e_num_layers,
        d_num_layers=d_num_layers,
        num_heads=num_heads,
        dropout_prob=dropout_prob,
        device=device
    )

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = build_transformer(input_size=3, embed_size=16, hidden_size=64, e_num_layers=2, d_num_layers=2, num_heads=4, dropout_prob=0.1, device=device)

# %%
# caluclate the number of parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 15,473 trainable parameters

# %%
# Fetch a single batch from train_loader
X_batch, y_batch = next(iter(train_loader))

# Check the shape directly from the DataLoader
X_batch, y_batch = next(iter(train_loader))
print("X_batch shape:", X_batch.shape)  # Expected: (64, 400, 3)
print("y_batch shape:", y_batch.shape)  # Expected: (64, 400)
# Out:
# X_batch shape: torch.Size([64, 400, 3])
# y_batch shape: torch.Size([64, 400])

# %%
# Forward pass through the model
output = model(X_batch, y_batch)

# Check output shapes
print("Output shape:", output.shape)  # Expected shape: (batch_size, seq_len, 1)
print("Target shape:", y_batch.shape)  # Expected shape: (batch_size, seq_len, 1)
# Out:
# Shape of X before embedding: torch.Size([64, 400, 3])
# Shape of dec_input before embedding: torch.Size([64, 400])
# Shape of X after embedding: torch.Size([64, 400, 16])
# Shape of encoder output: torch.Size([64, 400, 16])
# Shape of dec_input after embedding: torch.Size([64, 400, 16])
# Shape of decoder output: torch.Size([64, 400, 16])
# Shape of output after output layer: torch.Size([64, 400, 1])
# Output shape: torch.Size([64, 400, 1])
# Target shape: torch.Size([64, 400])

# %%
import optuna
import numpy as np

def objective(trial):
    # Suggest the number of heads
    num_heads = trial.suggest_int("num_heads", 2, 8)
    # Ensure embed_size is divisible by num_heads
    embed_size = trial.suggest_categorical("embed_size", [h * num_heads for h in range(2, 9)])  # Multiples of num_heads
    hidden_size = trial.suggest_int("hidden_size", 64, 256)
    e_num_layers = trial.suggest_int("e_num_layers", 1, 4)
    d_num_layers = trial.suggest_int("d_num_layers", 1, 4)
    dropout_prob = trial.suggest_float("dropout_prob", 0.1, 0.3)
    learning_rate = trial.suggest_float("lr", 1e-5, 1e-3)
    
    # Initialize the Transformer model with suggested hyperparameters
    model = TransformerModel(
        input_size=3,
        output_size=1,
        embed_size=embed_size,
        hidden_size=hidden_size,
        e_num_layers=e_num_layers,
        d_num_layers=d_num_layers,
        num_heads=num_heads,
        dropout_prob=dropout_prob,
        device=device
    )
    model.to(device)

    # Define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    # Training loop (for a few epochs to get an idea of performance)
    num_epochs = 5  # You can increase this for more thorough tuning
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            loss = model.training_step(X_batch, y_batch, optimizer)
            train_loss += loss * X_batch.size(0)
        
        avg_train_loss = train_loss / len(train_loader.dataset)

        # Validation loop
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_val, y_val in val_loader:
                X_val, y_val = X_val.to(device), y_val.to(device)
                loss = model.validation_step(X_val, y_val)
                val_loss += loss * X_val.size(0)
        
        avg_val_loss = val_loss / len(val_loader.dataset)
        
        # Report validation loss to Optuna
        trial.report(avg_val_loss, epoch)

        # Prune trial if it performs poorly
        if trial.should_prune():
            raise optuna.TrialPruned()
    
    return avg_val_loss

# %%
import optuna
import pickle

# Create the study and specify the direction as "minimize" to reduce validation loss
study = optuna.create_study(direction="minimize")

# Run the study with the defined objective function
study.optimize(objective, n_trials=100)  # Adjust the number of trials as needed

# Save the study object to a pickle file for future reference
with open("study.pkl", "wb") as f:
    pickle.dump(study, f)

# Save the best hyperparameters to a separate pickle file
best_params = study.best_params
with open("best_params.pkl", "wb") as f:
    pickle.dump(best_params, f)

print("Best hyperparameters found by Optuna:", best_params)
# Out:
# [I 2024-11-08 17:20:06,901] A new study created in memory with name: no-name-c888301d-72a0-41d2-b7ae-ccedc1d48eed
# Encoder output shape: torch.Size([64, 400, 24])
# Initial dec_input shape: torch.Size([64, 1, 1])
# Shape after embedding at timestep 0: torch.Size([64, 1, 24])
# Shape after embedding at timestep 1: torch.Size([64, 1, 24])
# Shape after embedding at timestep 2: torch.Size([64, 1, 24])
# Shape after embedding at timestep 3: torch.Size([64, 1, 24])
# Shape after embedding at timestep 4: torch.Size([64, 1, 24])
# Shape after embedding at timestep 5: torch.Size([64, 1, 24])
# Shape after embedding at timestep 6: torch.Size([64, 1, 24])
# Shape after embedding at timestep 7: torch.Size([64, 1, 24])
# Shape after embedding at timestep 8: torch.Size([64, 1, 24])
# Shape after embedding at timestep 9: torch.Size([64, 1, 24])
# Shape after embedding at timestep 10: torch.Size([64, 1, 24])
# Shape after embedding at timestep 11: torch.Size([64, 1, 24])
# Shape after embedding at timestep 12: torch.Size([64, 1, 24])
# Shape after embedding at timestep 13: torch.Size([64, 1, 24])
# Shape after embedding at timestep 14: torch.Size([64, 1, 24])
# Shape after embedding at timestep 15: torch.Size([64, 1, 24])
# Shape after embedding at timestep 16: torch.Size([64, 1, 24])
# Shape after embedding at timestep 17: torch.Size([64, 1, 24])
# Shape after embedding at timestep 18: torch.Size([64, 1, 24])
# Shape after embedding at timestep 19: torch.Size([64, 1, 24])
# Shape after embedding at timestep 20: torch.Size([64, 1, 24])
# Shape after embedding at timestep 21: torch.Size([64, 1, 24])
# Shape after embedding at timestep 22: torch.Size([64, 1, 24])
# Shape after embedding at timestep 23: torch.Size([64, 1, 24])
# Shape after embedding at timestep 24: torch.Size([64, 1, 24])
# Shape after embedding at timestep 25: torch.Size([64, 1, 24])
# Shape after embedding at timestep 26: torch.Size([64, 1, 24])
# Shape after embedding at timestep 27: torch.Size([64, 1, 24])
# Shape after embedding at timestep 28: torch.Size([64, 1, 24])
# Shape after embedding at timestep 29: torch.Size([64, 1, 24])
# Shape after embedding at timestep 30: torch.Size([64, 1, 24])
# Shape after embedding at timestep 31: torch.Size([64, 1, 24])
# Shape after embedding at timestep 32: torch.Size([64, 1, 24])
# Shape after embedding at timestep 33: torch.Size([64, 1, 24])
# Shape after embedding at timestep 34: torch.Size([64, 1, 24])
# Shape after embedding at timestep 35: torch.Size([64, 1, 24])
# Shape after embedding at timestep 36: torch.Size([64, 1, 24])
# Shape after embedding at timestep 37: torch.Size([64, 1, 24])
# Shape after embedding at timestep 38: torch.Size([64, 1, 24])
# Shape after embedding at timestep 39: torch.Size([64, 1, 24])
# Shape after embedding at timestep 40: torch.Size([64, 1, 24])
# Shape after embedding at timestep 41: torch.Size([64, 1, 24])
# Shape after embedding at timestep 42: torch.Size([64, 1, 24])
# Shape after embedding at timestep 43: torch.Size([64, 1, 24])
# Shape after embedding at timestep 44: torch.Size([64, 1, 24])
# Shape after embedding at timestep 45: torch.Size([64, 1, 24])
# Shape after embedding at timestep 46: torch.Size([64, 1, 24])
# Shape after embedding at timestep 47: torch.Size([64, 1, 24])
# Shape after embedding at timestep 48: torch.Size([64, 1, 24])
# Shape after embedding at timestep 49: torch.Size([64, 1, 24])
# Shape after embedding at timestep 50: torch.Size([64, 1, 24])
# Shape after embedding at timestep 51: torch.Size([64, 1, 24])
# Shape after embedding at timestep 52: torch.Size([64, 1, 24])
# Shape after embedding at timestep 53: torch.Size([64, 1, 24])
# Shape after embedding at timestep 54: torch.Size([64, 1, 24])
# Shape after embedding at timestep 55: torch.Size([64, 1, 24])
# Shape after embedding at timestep 56: torch.Size([64, 1, 24])
# Shape after embedding at timestep 57: torch.Size([64, 1, 24])
# Shape after embedding at timestep 58: torch.Size([64, 1, 24])
# Shape after embedding at timestep 59: torch.Size([64, 1, 24])
# Shape after embedding at timestep 60: torch.Size([64, 1, 24])
# Shape after embedding at timestep 61: torch.Size([64, 1, 24])
# Shape after embedding at timestep 62: torch.Size([64, 1, 24])
# Shape after embedding at timestep 63: torch.Size([64, 1, 24])
# Shape after embedding at timestep 64: torch.Size([64, 1, 24])
# Shape after embedding at timestep 65: torch.Size([64, 1, 24])
# Shape after embedding at timestep 66: torch.Size([64, 1, 24])
# Shape after embedding at timestep 67: torch.Size([64, 1, 24])
# Shape after embedding at timestep 68: torch.Size([64, 1, 24])
# Shape after embedding at timestep 69: torch.Size([64, 1, 24])
# Shape after embedding at timestep 70: torch.Size([64, 1, 24])
# Shape after embedding at timestep 71: torch.Size([64, 1, 24])
# Shape after embedding at timestep 72: torch.Size([64, 1, 24])
# Shape after embedding at timestep 73: torch.Size([64, 1, 24])
# Shape after embedding at timestep 74: torch.Size([64, 1, 24])
# Shape after embedding at timestep 75: torch.Size([64, 1, 24])
# Shape after embedding at timestep 76: torch.Size([64, 1, 24])
# Shape after embedding at timestep 77: torch.Size([64, 1, 24])
# Shape after embedding at timestep 78: torch.Size([64, 1, 24])
# Shape after embedding at timestep 79: torch.Size([64, 1, 24])
# Shape after embedding at timestep 80: torch.Size([64, 1, 24])
# Shape after embedding at timestep 81: torch.Size([64, 1, 24])
# Shape after embedding at timestep 82: torch.Size([64, 1, 24])
# Shape after embedding at timestep 83: torch.Size([64, 1, 24])
# Shape after embedding at timestep 84: torch.Size([64, 1, 24])
# Shape after embedding at timestep 85: torch.Size([64, 1, 24])
# Shape after embedding at timestep 86: torch.Size([64, 1, 24])
# Shape after embedding at timestep 87: torch.Size([64, 1, 24])
# Shape after embedding at timestep 88: torch.Size([64, 1, 24])
# Shape after embedding at timestep 89: torch.Size([64, 1, 24])
# Shape after embedding at timestep 90: torch.Size([64, 1, 24])
# Shape after embedding at timestep 91: torch.Size([64, 1, 24])
# Shape after embedding at timestep 92: torch.Size([64, 1, 24])
# Shape after embedding at timestep 93: torch.Size([64, 1, 24])
# Shape after embedding at timestep 94: torch.Size([64, 1, 24])
# Shape after embedding at timestep 95: torch.Size([64, 1, 24])
# Shape after embedding at timestep 96: torch.Size([64, 1, 24])
# Shape after embedding at timestep 97: torch.Size([64, 1, 24])
# Shape after embedding at timestep 98: torch.Size([64, 1, 24])
# Shape after embedding at timestep 99: torch.Size([64, 1, 24])
# Shape after embedding at timestep 100: torch.Size([64, 1, 24])
# Shape after embedding at timestep 101: torch.Size([64, 1, 24])
# Shape after embedding at timestep 102: torch.Size([64, 1, 24])
# Shape after embedding at timestep 103: torch.Size([64, 1, 24])
# Shape after embedding at timestep 104: torch.Size([64, 1, 24])
# Shape after embedding at timestep 105: torch.Size([64, 1, 24])
# Shape after embedding at timestep 106: torch.Size([64, 1, 24])
# Shape after embedding at timestep 107: torch.Size([64, 1, 24])
# Shape after embedding at timestep 108: torch.Size([64, 1, 24])
# Shape after embedding at timestep 109: torch.Size([64, 1, 24])
# Shape after embedding at timestep 110: torch.Size([64, 1, 24])
# Shape after embedding at timestep 111: torch.Size([64, 1, 24])
# Shape after embedding at timestep 112: torch.Size([64, 1, 24])
# Shape after embedding at timestep 113: torch.Size([64, 1, 24])
# Shape after embedding at timestep 114: torch.Size([64, 1, 24])
# Shape after embedding at timestep 115: torch.Size([64, 1, 24])
# Shape after embedding at timestep 116: torch.Size([64, 1, 24])
# Shape after embedding at timestep 117: torch.Size([64, 1, 24])
# Shape after embedding at timestep 118: torch.Size([64, 1, 24])
# Shape after embedding at timestep 119: torch.Size([64, 1, 24])
# Shape after embedding at timestep 120: torch.Size([64, 1, 24])
# Shape after embedding at timestep 121: torch.Size([64, 1, 24])
# Shape after embedding at timestep 122: torch.Size([64, 1, 24])
# Shape after embedding at timestep 123: torch.Size([64, 1, 24])
# Shape after embedding at timestep 124: torch.Size([64, 1, 24])
# Shape after embedding at timestep 125: torch.Size([64, 1, 24])
# Shape after embedding at timestep 126: torch.Size([64, 1, 24])
# Shape after embedding at timestep 127: torch.Size([64, 1, 24])
# Shape after embedding at timestep 128: torch.Size([64, 1, 24])
# Shape after embedding at timestep 129: torch.Size([64, 1, 24])
# Shape after embedding at timestep 130: torch.Size([64, 1, 24])
# Shape after embedding at timestep 131: torch.Size([64, 1, 24])
# Shape after embedding at timestep 132: torch.Size([64, 1, 24])
# Shape after embedding at timestep 133: torch.Size([64, 1, 24])
# Shape after embedding at timestep 134: torch.Size([64, 1, 24])
# Shape after embedding at timestep 135: torch.Size([64, 1, 24])
# Shape after embedding at timestep 136: torch.Size([64, 1, 24])
# Shape after embedding at timestep 137: torch.Size([64, 1, 24])
# Shape after embedding at timestep 138: torch.Size([64, 1, 24])
# Shape after embedding at timestep 139: torch.Size([64, 1, 24])
# Shape after embedding at timestep 140: torch.Size([64, 1, 24])
# Shape after embedding at timestep 141: torch.Size([64, 1, 24])
# Shape after embedding at timestep 142: torch.Size([64, 1, 24])
# Shape after embedding at timestep 143: torch.Size([64, 1, 24])
# Shape after embedding at timestep 144: torch.Size([64, 1, 24])
# Shape after embedding at timestep 145: torch.Size([64, 1, 24])
# Shape after embedding at timestep 146: torch.Size([64, 1, 24])
# Shape after embedding at timestep 147: torch.Size([64, 1, 24])
# Shape after embedding at timestep 148: torch.Size([64, 1, 24])
# Shape after embedding at timestep 149: torch.Size([64, 1, 24])
# Shape after embedding at timestep 150: torch.Size([64, 1, 24])
# Shape after embedding at timestep 151: torch.Size([64, 1, 24])
# Shape after embedding at timestep 152: torch.Size([64, 1, 24])
# Shape after embedding at timestep 153: torch.Size([64, 1, 24])
# Shape after embedding at timestep 154: torch.Size([64, 1, 24])
# Shape after embedding at timestep 155: torch.Size([64, 1, 24])
# Shape after embedding at timestep 156: torch.Size([64, 1, 24])
# Shape after embedding at timestep 157: torch.Size([64, 1, 24])
# Shape after embedding at timestep 158: torch.Size([64, 1, 24])
# Shape after embedding at timestep 159: torch.Size([64, 1, 24])
# Shape after embedding at timestep 160: torch.Size([64, 1, 24])
# Shape after embedding at timestep 161: torch.Size([64, 1, 24])
# Shape after embedding at timestep 162: torch.Size([64, 1, 24])
# Shape after embedding at timestep 163: torch.Size([64, 1, 24])
# Shape after embedding at timestep 164: torch.Size([64, 1, 24])
# Shape after embedding at timestep 165: torch.Size([64, 1, 24])
# Shape after embedding at timestep 166: torch.Size([64, 1, 24])
# Shape after embedding at timestep 167: torch.Size([64, 1, 24])
# Shape after embedding at timestep 168: torch.Size([64, 1, 24])
# Shape after embedding at timestep 169: torch.Size([64, 1, 24])
# Shape after embedding at timestep 170: torch.Size([64, 1, 24])
# Shape after embedding at timestep 171: torch.Size([64, 1, 24])
# Shape after embedding at timestep 172: torch.Size([64, 1, 24])
# Shape after embedding at timestep 173: torch.Size([64, 1, 24])
# Shape after embedding at timestep 174: torch.Size([64, 1, 24])
# Shape after embedding at timestep 175: torch.Size([64, 1, 24])
# Shape after embedding at timestep 176: torch.Size([64, 1, 24])
# Shape after embedding at timestep 177: torch.Size([64, 1, 24])
# Shape after embedding at timestep 178: torch.Size([64, 1, 24])
# Shape after embedding at timestep 179: torch.Size([64, 1, 24])
# Shape after embedding at timestep 180: torch.Size([64, 1, 24])
# Shape after embedding at timestep 181: torch.Size([64, 1, 24])
# Shape after embedding at timestep 182: torch.Size([64, 1, 24])
# Shape after embedding at timestep 183: torch.Size([64, 1, 24])
# Shape after embedding at timestep 184: torch.Size([64, 1, 24])
# Shape after embedding at timestep 185: torch.Size([64, 1, 24])
# Shape after embedding at timestep 186: torch.Size([64, 1, 24])
# Shape after embedding at timestep 187: torch.Size([64, 1, 24])
# Shape after embedding at timestep 188: torch.Size([64, 1, 24])
# Shape after embedding at timestep 189: torch.Size([64, 1, 24])
# Shape after embedding at timestep 190: torch.Size([64, 1, 24])
# Shape after embedding at timestep 191: torch.Size([64, 1, 24])
# Shape after embedding at timestep 192: torch.Size([64, 1, 24])
# Shape after embedding at timestep 193: torch.Size([64, 1, 24])
# Shape after embedding at timestep 194: torch.Size([64, 1, 24])
# Shape after embedding at timestep 195: torch.Size([64, 1, 24])
# Shape after embedding at timestep 196: torch.Size([64, 1, 24])
# Shape after embedding at timestep 197: torch.Size([64, 1, 24])
# Shape after embedding at timestep 198: torch.Size([64, 1, 24])
# Shape after embedding at timestep 199: torch.Size([64, 1, 24])
# Shape after embedding at timestep 200: torch.Size([64, 1, 24])
# Shape after embedding at timestep 201: torch.Size([64, 1, 24])
# Shape after embedding at timestep 202: torch.Size([64, 1, 24])
# Shape after embedding at timestep 203: torch.Size([64, 1, 24])
# Shape after embedding at timestep 204: torch.Size([64, 1, 24])
# Shape after embedding at timestep 205: torch.Size([64, 1, 24])
# Shape after embedding at timestep 206: torch.Size([64, 1, 24])
# Shape after embedding at timestep 207: torch.Size([64, 1, 24])
# Shape after embedding at timestep 208: torch.Size([64, 1, 24])
# Shape after embedding at timestep 209: torch.Size([64, 1, 24])
# Shape after embedding at timestep 210: torch.Size([64, 1, 24])
# Shape after embedding at timestep 211: torch.Size([64, 1, 24])
# Shape after embedding at timestep 212: torch.Size([64, 1, 24])
# Shape after embedding at timestep 213: torch.Size([64, 1, 24])
# Shape after embedding at timestep 214: torch.Size([64, 1, 24])
# Shape after embedding at timestep 215: torch.Size([64, 1, 24])
# Shape after embedding at timestep 216: torch.Size([64, 1, 24])
# Shape after embedding at timestep 217: torch.Size([64, 1, 24])
# Shape after embedding at timestep 218: torch.Size([64, 1, 24])
# Shape after embedding at timestep 219: torch.Size([64, 1, 24])
# Shape after embedding at timestep 220: torch.Size([64, 1, 24])
# Shape after embedding at timestep 221: torch.Size([64, 1, 24])
# Shape after embedding at timestep 222: torch.Size([64, 1, 24])
# Shape after embedding at timestep 223: torch.Size([64, 1, 24])
# Shape after embedding at timestep 224: torch.Size([64, 1, 24])
# Shape after embedding at timestep 225: torch.Size([64, 1, 24])
# Shape after embedding at timestep 226: torch.Size([64, 1, 24])
# Shape after embedding at timestep 227: torch.Size([64, 1, 24])
# Shape after embedding at timestep 228: torch.Size([64, 1, 24])
# Shape after embedding at timestep 229: torch.Size([64, 1, 24])
# Shape after embedding at timestep 230: torch.Size([64, 1, 24])
# Shape after embedding at timestep 231: torch.Size([64, 1, 24])
# Shape after embedding at timestep 232: torch.Size([64, 1, 24])
# Shape after embedding at timestep 233: torch.Size([64, 1, 24])
# Shape after embedding at timestep 234: torch.Size([64, 1, 24])
# Shape after embedding at timestep 235: torch.Size([64, 1, 24])
# Shape after embedding at timestep 236: torch.Size([64, 1, 24])
# Shape after embedding at timestep 237: torch.Size([64, 1, 24])
# Shape after embedding at timestep 238: torch.Size([64, 1, 24])
# Shape after embedding at timestep 239: torch.Size([64, 1, 24])
# Shape after embedding at timestep 240: torch.Size([64, 1, 24])
# Shape after embedding at timestep 241: torch.Size([64, 1, 24])
# Shape after embedding at timestep 242: torch.Size([64, 1, 24])
# Shape after embedding at timestep 243: torch.Size([64, 1, 24])
# Shape after embedding at timestep 244: torch.Size([64, 1, 24])
# Shape after embedding at timestep 245: torch.Size([64, 1, 24])
# Shape after embedding at timestep 246: torch.Size([64, 1, 24])
# Shape after embedding at timestep 247: torch.Size([64, 1, 24])
# Shape after embedding at timestep 248: torch.Size([64, 1, 24])
# Shape after embedding at timestep 249: torch.Size([64, 1, 24])
# Shape after embedding at timestep 250: torch.Size([64, 1, 24])
# Shape after embedding at timestep 251: torch.Size([64, 1, 24])
# Shape after embedding at timestep 252: torch.Size([64, 1, 24])
# Shape after embedding at timestep 253: torch.Size([64, 1, 24])
# Shape after embedding at timestep 254: torch.Size([64, 1, 24])
# Shape after embedding at timestep 255: torch.Size([64, 1, 24])
# Shape after embedding at timestep 256: torch.Size([64, 1, 24])
# Shape after embedding at timestep 257: torch.Size([64, 1, 24])
# Shape after embedding at timestep 258: torch.Size([64, 1, 24])
# Shape after embedding at timestep 259: torch.Size([64, 1, 24])
# Shape after embedding at timestep 260: torch.Size([64, 1, 24])
# Shape after embedding at timestep 261: torch.Size([64, 1, 24])
# Shape after embedding at timestep 262: torch.Size([64, 1, 24])
# Shape after embedding at timestep 263: torch.Size([64, 1, 24])
# Shape after embedding at timestep 264: torch.Size([64, 1, 24])
# Shape after embedding at timestep 265: torch.Size([64, 1, 24])
# Shape after embedding at timestep 266: torch.Size([64, 1, 24])
# Shape after embedding at timestep 267: torch.Size([64, 1, 24])
# Shape after embedding at timestep 268: torch.Size([64, 1, 24])
# Shape after embedding at timestep 269: torch.Size([64, 1, 24])
# Shape after embedding at timestep 270: torch.Size([64, 1, 24])
# Shape after embedding at timestep 271: torch.Size([64, 1, 24])
# Shape after embedding at timestep 272: torch.Size([64, 1, 24])
# Shape after embedding at timestep 273: torch.Size([64, 1, 24])
# Shape after embedding at timestep 274: torch.Size([64, 1, 24])
# Shape after embedding at timestep 275: torch.Size([64, 1, 24])
# Shape after embedding at timestep 276: torch.Size([64, 1, 24])
# Shape after embedding at timestep 277: torch.Size([64, 1, 24])
# Shape after embedding at timestep 278: torch.Size([64, 1, 24])
# Shape after embedding at timestep 279: torch.Size([64, 1, 24])
# Shape after embedding at timestep 280: torch.Size([64, 1, 24])
# Shape after embedding at timestep 281: torch.Size([64, 1, 24])
# Shape after embedding at timestep 282: torch.Size([64, 1, 24])
# Shape after embedding at timestep 283: torch.Size([64, 1, 24])
# Shape after embedding at timestep 284: torch.Size([64, 1, 24])
# Shape after embedding at timestep 285: torch.Size([64, 1, 24])
# Shape after embedding at timestep 286: torch.Size([64, 1, 24])
# Shape after embedding at timestep 287: torch.Size([64, 1, 24])
# Shape after embedding at timestep 288: torch.Size([64, 1, 24])
# Shape after embedding at timestep 289: torch.Size([64, 1, 24])
# Shape after embedding at timestep 290: torch.Size([64, 1, 24])
# Shape after embedding at timestep 291: torch.Size([64, 1, 24])
# Shape after embedding at timestep 292: torch.Size([64, 1, 24])
# Shape after embedding at timestep 293: torch.Size([64, 1, 24])
# Shape after embedding at timestep 294: torch.Size([64, 1, 24])
# Shape after embedding at timestep 295: torch.Size([64, 1, 24])
# Shape after embedding at timestep 296: torch.Size([64, 1, 24])
# Shape after embedding at timestep 297: torch.Size([64, 1, 24])
# Shape after embedding at timestep 298: torch.Size([64, 1, 24])
# Shape after embedding at timestep 299: torch.Size([64, 1, 24])
# Shape after embedding at timestep 300: torch.Size([64, 1, 24])
# Shape after embedding at timestep 301: torch.Size([64, 1, 24])
# Shape after embedding at timestep 302: torch.Size([64, 1, 24])
# Shape after embedding at timestep 303: torch.Size([64, 1, 24])
# Shape after embedding at timestep 304: torch.Size([64, 1, 24])
# Shape after embedding at timestep 305: torch.Size([64, 1, 24])
# Shape after embedding at timestep 306: torch.Size([64, 1, 24])
# Shape after embedding at timestep 307: torch.Size([64, 1, 24])
# Shape after embedding at timestep 308: torch.Size([64, 1, 24])
# Shape after embedding at timestep 309: torch.Size([64, 1, 24])
# Shape after embedding at timestep 310: torch.Size([64, 1, 24])
# Shape after embedding at timestep 311: torch.Size([64, 1, 24])
# Shape after embedding at timestep 312: torch.Size([64, 1, 24])
# Shape after embedding at timestep 313: torch.Size([64, 1, 24])
# Shape after embedding at timestep 314: torch.Size([64, 1, 24])
# Shape after embedding at timestep 315: torch.Size([64, 1, 24])
# Shape after embedding at timestep 316: torch.Size([64, 1, 24])
# Shape after embedding at timestep 317: torch.Size([64, 1, 24])
# Shape after embedding at timestep 318: torch.Size([64, 1, 24])
# Shape after embedding at timestep 319: torch.Size([64, 1, 24])
# Shape after embedding at timestep 320: torch.Size([64, 1, 24])
# Shape after embedding at timestep 321: torch.Size([64, 1, 24])
# Shape after embedding at timestep 322: torch.Size([64, 1, 24])
# Shape after embedding at timestep 323: torch.Size([64, 1, 24])
# Shape after embedding at timestep 324: torch.Size([64, 1, 24])
# Shape after embedding at timestep 325: torch.Size([64, 1, 24])
# Shape after embedding at timestep 326: torch.Size([64, 1, 24])
# Shape after embedding at timestep 327: torch.Size([64, 1, 24])
# Shape after embedding at timestep 328: torch.Size([64, 1, 24])
# Shape after embedding at timestep 329: torch.Size([64, 1, 24])
# Shape after embedding at timestep 330: torch.Size([64, 1, 24])
# Shape after embedding at timestep 331: torch.Size([64, 1, 24])
# Shape after embedding at timestep 332: torch.Size([64, 1, 24])
# Shape after embedding at timestep 333: torch.Size([64, 1, 24])
# Shape after embedding at timestep 334: torch.Size([64, 1, 24])
# Shape after embedding at timestep 335: torch.Size([64, 1, 24])
# Shape after embedding at timestep 336: torch.Size([64, 1, 24])
# Shape after embedding at timestep 337: torch.Size([64, 1, 24])
# Shape after embedding at timestep 338: torch.Size([64, 1, 24])
# Shape after embedding at timestep 339: torch.Size([64, 1, 24])
# Shape after embedding at timestep 340: torch.Size([64, 1, 24])
# Shape after embedding at timestep 341: torch.Size([64, 1, 24])
# Shape after embedding at timestep 342: torch.Size([64, 1, 24])
# Shape after embedding at timestep 343: torch.Size([64, 1, 24])
# Shape after embedding at timestep 344: torch.Size([64, 1, 24])
# Shape after embedding at timestep 345: torch.Size([64, 1, 24])
# Shape after embedding at timestep 346: torch.Size([64, 1, 24])
# Shape after embedding at timestep 347: torch.Size([64, 1, 24])
# Shape after embedding at timestep 348: torch.Size([64, 1, 24])
# Shape after embedding at timestep 349: torch.Size([64, 1, 24])
# Shape after embedding at timestep 350: torch.Size([64, 1, 24])
# Shape after embedding at timestep 351: torch.Size([64, 1, 24])
# Shape after embedding at timestep 352: torch.Size([64, 1, 24])
# Shape after embedding at timestep 353: torch.Size([64, 1, 24])
# Shape after embedding at timestep 354: torch.Size([64, 1, 24])
# Shape after embedding at timestep 355: torch.Size([64, 1, 24])
# Shape after embedding at timestep 356: torch.Size([64, 1, 24])
# Shape after embedding at timestep 357: torch.Size([64, 1, 24])
# Shape after embedding at timestep 358: torch.Size([64, 1, 24])
# Shape after embedding at timestep 359: torch.Size([64, 1, 24])
# Shape after embedding at timestep 360: torch.Size([64, 1, 24])
# Shape after embedding at timestep 361: torch.Size([64, 1, 24])
# Shape after embedding at timestep 362: torch.Size([64, 1, 24])
# Shape after embedding at timestep 363: torch.Size([64, 1, 24])
# Shape after embedding at timestep 364: torch.Size([64, 1, 24])
# Shape after embedding at timestep 365: torch.Size([64, 1, 24])
# Shape after embedding at timestep 366: torch.Size([64, 1, 24])
# Shape after embedding at timestep 367: torch.Size([64, 1, 24])
# Shape after embedding at timestep 368: torch.Size([64, 1, 24])
# Shape after embedding at timestep 369: torch.Size([64, 1, 24])
# Shape after embedding at timestep 370: torch.Size([64, 1, 24])
# Shape after embedding at timestep 371: torch.Size([64, 1, 24])
# Shape after embedding at timestep 372: torch.Size([64, 1, 24])
# Shape after embedding at timestep 373: torch.Size([64, 1, 24])
# Shape after embedding at timestep 374: torch.Size([64, 1, 24])
# Shape after embedding at timestep 375: torch.Size([64, 1, 24])
# Shape after embedding at timestep 376: torch.Size([64, 1, 24])
# Shape after embedding at timestep 377: torch.Size([64, 1, 24])
# Shape after embedding at timestep 378: torch.Size([64, 1, 24])
# Shape after embedding at timestep 379: torch.Size([64, 1, 24])
# Shape after embedding at timestep 380: torch.Size([64, 1, 24])
# Shape after embedding at timestep 381: torch.Size([64, 1, 24])
# Shape after embedding at timestep 382: torch.Size([64, 1, 24])
# Shape after embedding at timestep 383: torch.Size([64, 1, 24])
# Shape after embedding at timestep 384: torch.Size([64, 1, 24])
# Shape after embedding at timestep 385: torch.Size([64, 1, 24])
# Shape after embedding at timestep 386: torch.Size([64, 1, 24])
# Shape after embedding at timestep 387: torch.Size([64, 1, 24])
# Shape after embedding at timestep 388: torch.Size([64, 1, 24])
# Shape after embedding at timestep 389: torch.Size([64, 1, 24])
# Shape after embedding at timestep 390: torch.Size([64, 1, 24])
# Shape after embedding at timestep 391: torch.Size([64, 1, 24])
# Shape after embedding at timestep 392: torch.Size([64, 1, 24])
# Shape after embedding at timestep 393: torch.Size([64, 1, 24])
# Shape after embedding at timestep 394: torch.Size([64, 1, 24])
# Shape after embedding at timestep 395: torch.Size([64, 1, 24])
# Shape after embedding at timestep 396: torch.Size([64, 1, 24])
# Shape after embedding at timestep 397: torch.Size([64, 1, 24])
# Shape after embedding at timestep 398: torch.Size([64, 1, 24])
# Shape after embedding at timestep 399: torch.Size([64, 1, 24])
# Encoder output shape: torch.Size([64, 400, 24])
# Initial dec_input shape: torch.Size([64, 1, 1])
# Shape after embedding at timestep 0: torch.Size([64, 1, 24])
# Shape after embedding at timestep 1: torch.Size([64, 1, 24])
# Shape after embedding at timestep 2: torch.Size([64, 1, 24])
# Shape after embedding at timestep 3: torch.Size([64, 1, 24])
# Shape after embedding at timestep 4: torch.Size([64, 1, 24])
# Shape after embedding at timestep 5: torch.Size([64, 1, 24])
# Shape after embedding at timestep 6: torch.Size([64, 1, 24])
# Shape after embedding at timestep 7: torch.Size([64, 1, 24])
# Shape after embedding at timestep 8: torch.Size([64, 1, 24])
# Shape after embedding at timestep 9: torch.Size([64, 1, 24])
# Shape after embedding at timestep 10: torch.Size([64, 1, 24])
# Shape after embedding at timestep 11: torch.Size([64, 1, 24])
# Shape after embedding at timestep 12: torch.Size([64, 1, 24])
# Shape after embedding at timestep 13: torch.Size([64, 1, 24])
# Shape after embedding at timestep 14: torch.Size([64, 1, 24])
# Shape after embedding at timestep 15: torch.Size([64, 1, 24])
# Shape after embedding at timestep 16: torch.Size([64, 1, 24])
# Shape after embedding at timestep 17: torch.Size([64, 1, 24])
# Shape after embedding at timestep 18: torch.Size([64, 1, 24])
# Shape after embedding at timestep 19: torch.Size([64, 1, 24])
# Shape after embedding at timestep 20: torch.Size([64, 1, 24])
# Shape after embedding at timestep 21: torch.Size([64, 1, 24])
# Shape after embedding at timestep 22: torch.Size([64, 1, 24])
# Shape after embedding at timestep 23: torch.Size([64, 1, 24])
# Shape after embedding at timestep 24: torch.Size([64, 1, 24])
# Shape after embedding at timestep 25: torch.Size([64, 1, 24])
# Shape after embedding at timestep 26: torch.Size([64, 1, 24])
# Shape after embedding at timestep 27: torch.Size([64, 1, 24])
# Shape after embedding at timestep 28: torch.Size([64, 1, 24])
# Shape after embedding at timestep 29: torch.Size([64, 1, 24])
# Shape after embedding at timestep 30: torch.Size([64, 1, 24])
# Shape after embedding at timestep 31: torch.Size([64, 1, 24])
# Shape after embedding at timestep 32: torch.Size([64, 1, 24])
# Shape after embedding at timestep 33: torch.Size([64, 1, 24])
# Shape after embedding at timestep 34: torch.Size([64, 1, 24])
# Shape after embedding at timestep 35: torch.Size([64, 1, 24])
# Shape after embedding at timestep 36: torch.Size([64, 1, 24])
# Shape after embedding at timestep 37: torch.Size([64, 1, 24])
# Shape after embedding at timestep 38: torch.Size([64, 1, 24])
# Shape after embedding at timestep 39: torch.Size([64, 1, 24])
# Shape after embedding at timestep 40: torch.Size([64, 1, 24])
# Shape after embedding at timestep 41: torch.Size([64, 1, 24])
# Shape after embedding at timestep 42: torch.Size([64, 1, 24])
# Shape after embedding at timestep 43: torch.Size([64, 1, 24])
# Shape after embedding at timestep 44: torch.Size([64, 1, 24])
# Shape after embedding at timestep 45: torch.Size([64, 1, 24])
# Shape after embedding at timestep 46: torch.Size([64, 1, 24])
# Shape after embedding at timestep 47: torch.Size([64, 1, 24])
# Shape after embedding at timestep 48: torch.Size([64, 1, 24])
# Shape after embedding at timestep 49: torch.Size([64, 1, 24])
# Shape after embedding at timestep 50: torch.Size([64, 1, 24])
# Shape after embedding at timestep 51: torch.Size([64, 1, 24])
# Shape after embedding at timestep 52: torch.Size([64, 1, 24])
# Shape after embedding at timestep 53: torch.Size([64, 1, 24])
# Shape after embedding at timestep 54: torch.Size([64, 1, 24])
# Shape after embedding at timestep 55: torch.Size([64, 1, 24])
# Shape after embedding at timestep 56: torch.Size([64, 1, 24])
# Shape after embedding at timestep 57: torch.Size([64, 1, 24])
# Shape after embedding at timestep 58: torch.Size([64, 1, 24])
# Shape after embedding at timestep 59: torch.Size([64, 1, 24])
# Shape after embedding at timestep 60: torch.Size([64, 1, 24])
# Shape after embedding at timestep 61: torch.Size([64, 1, 24])
# Shape after embedding at timestep 62: torch.Size([64, 1, 24])
# Shape after embedding at timestep 63: torch.Size([64, 1, 24])
# Shape after embedding at timestep 64: torch.Size([64, 1, 24])
# Shape after embedding at timestep 65: torch.Size([64, 1, 24])
# Shape after embedding at timestep 66: torch.Size([64, 1, 24])
# Shape after embedding at timestep 67: torch.Size([64, 1, 24])
# Shape after embedding at timestep 68: torch.Size([64, 1, 24])
# Shape after embedding at timestep 69: torch.Size([64, 1, 24])
# Shape after embedding at timestep 70: torch.Size([64, 1, 24])
# Shape after embedding at timestep 71: torch.Size([64, 1, 24])
# Shape after embedding at timestep 72: torch.Size([64, 1, 24])
# Shape after embedding at timestep 73: torch.Size([64, 1, 24])
# Shape after embedding at timestep 74: torch.Size([64, 1, 24])
# Shape after embedding at timestep 75: torch.Size([64, 1, 24])
# Shape after embedding at timestep 76: torch.Size([64, 1, 24])
# Shape after embedding at timestep 77: torch.Size([64, 1, 24])
# Shape after embedding at timestep 78: torch.Size([64, 1, 24])
# Shape after embedding at timestep 79: torch.Size([64, 1, 24])
# Shape after embedding at timestep 80: torch.Size([64, 1, 24])
# Shape after embedding at timestep 81: torch.Size([64, 1, 24])
# Shape after embedding at timestep 82: torch.Size([64, 1, 24])
# Shape after embedding at timestep 83: torch.Size([64, 1, 24])
# Shape after embedding at timestep 84: torch.Size([64, 1, 24])
# Shape after embedding at timestep 85: torch.Size([64, 1, 24])
# Shape after embedding at timestep 86: torch.Size([64, 1, 24])
# Shape after embedding at timestep 87: torch.Size([64, 1, 24])
# Shape after embedding at timestep 88: torch.Size([64, 1, 24])
# Shape after embedding at timestep 89: torch.Size([64, 1, 24])
# Shape after embedding at timestep 90: torch.Size([64, 1, 24])
# Shape after embedding at timestep 91: torch.Size([64, 1, 24])
# Shape after embedding at timestep 92: torch.Size([64, 1, 24])
# Shape after embedding at timestep 93: torch.Size([64, 1, 24])
# Shape after embedding at timestep 94: torch.Size([64, 1, 24])
# Shape after embedding at timestep 95: torch.Size([64, 1, 24])
# Shape after embedding at timestep 96: torch.Size([64, 1, 24])
# Shape after embedding at timestep 97: torch.Size([64, 1, 24])
# Shape after embedding at timestep 98: torch.Size([64, 1, 24])
# Shape after embedding at timestep 99: torch.Size([64, 1, 24])
# Shape after embedding at timestep 100: torch.Size([64, 1, 24])
# Shape after embedding at timestep 101: torch.Size([64, 1, 24])
# Shape after embedding at timestep 102: torch.Size([64, 1, 24])
# Shape after embedding at timestep 103: torch.Size([64, 1, 24])
# Shape after embedding at timestep 104: torch.Size([64, 1, 24])
# Shape after embedding at timestep 105: torch.Size([64, 1, 24])
# Shape after embedding at timestep 106: torch.Size([64, 1, 24])
# Shape after embedding at timestep 107: torch.Size([64, 1, 24])
# Shape after embedding at timestep 108: torch.Size([64, 1, 24])
# Shape after embedding at timestep 109: torch.Size([64, 1, 24])
# Shape after embedding at timestep 110: torch.Size([64, 1, 24])
# Shape after embedding at timestep 111: torch.Size([64, 1, 24])
# Shape after embedding at timestep 112: torch.Size([64, 1, 24])
# Shape after embedding at timestep 113: torch.Size([64, 1, 24])
# Shape after embedding at timestep 114: torch.Size([64, 1, 24])
# Shape after embedding at timestep 115: torch.Size([64, 1, 24])
# Shape after embedding at timestep 116: torch.Size([64, 1, 24])
# Shape after embedding at timestep 117: torch.Size([64, 1, 24])
# Shape after embedding at timestep 118: torch.Size([64, 1, 24])
# Shape after embedding at timestep 119: torch.Size([64, 1, 24])
# Shape after embedding at timestep 120: torch.Size([64, 1, 24])
# Shape after embedding at timestep 121: torch.Size([64, 1, 24])
# Shape after embedding at timestep 122: torch.Size([64, 1, 24])
# Shape after embedding at timestep 123: torch.Size([64, 1, 24])
# Shape after embedding at timestep 124: torch.Size([64, 1, 24])
# Shape after embedding at timestep 125: torch.Size([64, 1, 24])
# Shape after embedding at timestep 126: torch.Size([64, 1, 24])
# Shape after embedding at timestep 127: torch.Size([64, 1, 24])
# Shape after embedding at timestep 128: torch.Size([64, 1, 24])
# Shape after embedding at timestep 129: torch.Size([64, 1, 24])
# Shape after embedding at timestep 130: torch.Size([64, 1, 24])
# Shape after embedding at timestep 131: torch.Size([64, 1, 24])
# Shape after embedding at timestep 132: torch.Size([64, 1, 24])
# Shape after embedding at timestep 133: torch.Size([64, 1, 24])
# Shape after embedding at timestep 134: torch.Size([64, 1, 24])
# Shape after embedding at timestep 135: torch.Size([64, 1, 24])
# Shape after embedding at timestep 136: torch.Size([64, 1, 24])
# Shape after embedding at timestep 137: torch.Size([64, 1, 24])
# Shape after embedding at timestep 138: torch.Size([64, 1, 24])
# Shape after embedding at timestep 139: torch.Size([64, 1, 24])
# Shape after embedding at timestep 140: torch.Size([64, 1, 24])
# Shape after embedding at timestep 141: torch.Size([64, 1, 24])
# Shape after embedding at timestep 142: torch.Size([64, 1, 24])
# Shape after embedding at timestep 143: torch.Size([64, 1, 24])
# Shape after embedding at timestep 144: torch.Size([64, 1, 24])
# Shape after embedding at timestep 145: torch.Size([64, 1, 24])
# Shape after embedding at timestep 146: torch.Size([64, 1, 24])
# Shape after embedding at timestep 147: torch.Size([64, 1, 24])
# Shape after embedding at timestep 148: torch.Size([64, 1, 24])
# Shape after embedding at timestep 149: torch.Size([64, 1, 24])
# Shape after embedding at timestep 150: torch.Size([64, 1, 24])
# Shape after embedding at timestep 151: torch.Size([64, 1, 24])
# Shape after embedding at timestep 152: torch.Size([64, 1, 24])
# Shape after embedding at timestep 153: torch.Size([64, 1, 24])
# Shape after embedding at timestep 154: torch.Size([64, 1, 24])
# Shape after embedding at timestep 155: torch.Size([64, 1, 24])
# Shape after embedding at timestep 156: torch.Size([64, 1, 24])
# Shape after embedding at timestep 157: torch.Size([64, 1, 24])
# Shape after embedding at timestep 158: torch.Size([64, 1, 24])
# Shape after embedding at timestep 159: torch.Size([64, 1, 24])
# Shape after embedding at timestep 160: torch.Size([64, 1, 24])
# Shape after embedding at timestep 161: torch.Size([64, 1, 24])
# Shape after embedding at timestep 162: torch.Size([64, 1, 24])
# Shape after embedding at timestep 163: torch.Size([64, 1, 24])
# Shape after embedding at timestep 164: torch.Size([64, 1, 24])
# Shape after embedding at timestep 165: torch.Size([64, 1, 24])
# Shape after embedding at timestep 166: torch.Size([64, 1, 24])
# Shape after embedding at timestep 167: torch.Size([64, 1, 24])
# Shape after embedding at timestep 168: torch.Size([64, 1, 24])
# Shape after embedding at timestep 169: torch.Size([64, 1, 24])
# Shape after embedding at timestep 170: torch.Size([64, 1, 24])
# Shape after embedding at timestep 171: torch.Size([64, 1, 24])
# Shape after embedding at timestep 172: torch.Size([64, 1, 24])
# Shape after embedding at timestep 173: torch.Size([64, 1, 24])
# Shape after embedding at timestep 174: torch.Size([64, 1, 24])
# Shape after embedding at timestep 175: torch.Size([64, 1, 24])
# Shape after embedding at timestep 176: torch.Size([64, 1, 24])
# Shape after embedding at timestep 177: torch.Size([64, 1, 24])
# Shape after embedding at timestep 178: torch.Size([64, 1, 24])
# Shape after embedding at timestep 179: torch.Size([64, 1, 24])
# Shape after embedding at timestep 180: torch.Size([64, 1, 24])
# Shape after embedding at timestep 181: torch.Size([64, 1, 24])
# Shape after embedding at timestep 182: torch.Size([64, 1, 24])
# Shape after embedding at timestep 183: torch.Size([64, 1, 24])
# Shape after embedding at timestep 184: torch.Size([64, 1, 24])
# Shape after embedding at timestep 185: torch.Size([64, 1, 24])
# Shape after embedding at timestep 186: torch.Size([64, 1, 24])
# Shape after embedding at timestep 187: torch.Size([64, 1, 24])
# Shape after embedding at timestep 188: torch.Size([64, 1, 24])
# Shape after embedding at timestep 189: torch.Size([64, 1, 24])
# Shape after embedding at timestep 190: torch.Size([64, 1, 24])
# Shape after embedding at timestep 191: torch.Size([64, 1, 24])
# Shape after embedding at timestep 192: torch.Size([64, 1, 24])
# Shape after embedding at timestep 193: torch.Size([64, 1, 24])
# Shape after embedding at timestep 194: torch.Size([64, 1, 24])
# Shape after embedding at timestep 195: torch.Size([64, 1, 24])
# Shape after embedding at timestep 196: torch.Size([64, 1, 24])
# Shape after embedding at timestep 197: torch.Size([64, 1, 24])
# Shape after embedding at timestep 198: torch.Size([64, 1, 24])
# Shape after embedding at timestep 199: torch.Size([64, 1, 24])
# Shape after embedding at timestep 200: torch.Size([64, 1, 24])
# Shape after embedding at timestep 201: torch.Size([64, 1, 24])
# Shape after embedding at timestep 202: torch.Size([64, 1, 24])
# Shape after embedding at timestep 203: torch.Size([64, 1, 24])
# Shape after embedding at timestep 204: torch.Size([64, 1, 24])
# Shape after embedding at timestep 205: torch.Size([64, 1, 24])
# Shape after embedding at timestep 206: torch.Size([64, 1, 24])
# Shape after embedding at timestep 207: torch.Size([64, 1, 24])
# Shape after embedding at timestep 208: torch.Size([64, 1, 24])
# Shape after embedding at timestep 209: torch.Size([64, 1, 24])
# Shape after embedding at timestep 210: torch.Size([64, 1, 24])
# Shape after embedding at timestep 211: torch.Size([64, 1, 24])
# Shape after embedding at timestep 212: torch.Size([64, 1, 24])
# Shape after embedding at timestep 213: torch.Size([64, 1, 24])
# Shape after embedding at timestep 214: torch.Size([64, 1, 24])
# Shape after embedding at timestep 215: torch.Size([64, 1, 24])
# Shape after embedding at timestep 216: torch.Size([64, 1, 24])
# Shape after embedding at timestep 217: torch.Size([64, 1, 24])
# Shape after embedding at timestep 218: torch.Size([64, 1, 24])
# Shape after embedding at timestep 219: torch.Size([64, 1, 24])
# Shape after embedding at timestep 220: torch.Size([64, 1, 24])
# Shape after embedding at timestep 221: torch.Size([64, 1, 24])
# Shape after embedding at timestep 222: torch.Size([64, 1, 24])
# Shape after embedding at timestep 223: torch.Size([64, 1, 24])
# Shape after embedding at timestep 224: torch.Size([64, 1, 24])
# Shape after embedding at timestep 225: torch.Size([64, 1, 24])
# Shape after embedding at timestep 226: torch.Size([64, 1, 24])
# Shape after embedding at timestep 227: torch.Size([64, 1, 24])
# Shape after embedding at timestep 228: torch.Size([64, 1, 24])
# Shape after embedding at timestep 229: torch.Size([64, 1, 24])
# Shape after embedding at timestep 230: torch.Size([64, 1, 24])
# Shape after embedding at timestep 231: torch.Size([64, 1, 24])
# Shape after embedding at timestep 232: torch.Size([64, 1, 24])
# Shape after embedding at timestep 233: torch.Size([64, 1, 24])
# Shape after embedding at timestep 234: torch.Size([64, 1, 24])
# Shape after embedding at timestep 235: torch.Size([64, 1, 24])
# Shape after embedding at timestep 236: torch.Size([64, 1, 24])
# Shape after embedding at timestep 237: torch.Size([64, 1, 24])
# Shape after embedding at timestep 238: torch.Size([64, 1, 24])
# Shape after embedding at timestep 239: torch.Size([64, 1, 24])
# Shape after embedding at timestep 240: torch.Size([64, 1, 24])
# Shape after embedding at timestep 241: torch.Size([64, 1, 24])
# Shape after embedding at timestep 242: torch.Size([64, 1, 24])
# Shape after embedding at timestep 243: torch.Size([64, 1, 24])
# Shape after embedding at timestep 244: torch.Size([64, 1, 24])
# Shape after embedding at timestep 245: torch.Size([64, 1, 24])
# Shape after embedding at timestep 246: torch.Size([64, 1, 24])
# Shape after embedding at timestep 247: torch.Size([64, 1, 24])
# Shape after embedding at timestep 248: torch.Size([64, 1, 24])
# Shape after embedding at timestep 249: torch.Size([64, 1, 24])
# Shape after embedding at timestep 250: torch.Size([64, 1, 24])
# Shape after embedding at timestep 251: torch.Size([64, 1, 24])
# Shape after embedding at timestep 252: torch.Size([64, 1, 24])
# Shape after embedding at timestep 253: torch.Size([64, 1, 24])
# Shape after embedding at timestep 254: torch.Size([64, 1, 24])
# Shape after embedding at timestep 255: torch.Size([64, 1, 24])
# Shape after embedding at timestep 256: torch.Size([64, 1, 24])
# Shape after embedding at timestep 257: torch.Size([64, 1, 24])
# Shape after embedding at timestep 258: torch.Size([64, 1, 24])
# Shape after embedding at timestep 259: torch.Size([64, 1, 24])
# Shape after embedding at timestep 260: torch.Size([64, 1, 24])
# Shape after embedding at timestep 261: torch.Size([64, 1, 24])
# Shape after embedding at timestep 262: torch.Size([64, 1, 24])
# Shape after embedding at timestep 263: torch.Size([64, 1, 24])
# Shape after embedding at timestep 264: torch.Size([64, 1, 24])
# Shape after embedding at timestep 265: torch.Size([64, 1, 24])
# Shape after embedding at timestep 266: torch.Size([64, 1, 24])
# Shape after embedding at timestep 267: torch.Size([64, 1, 24])
# Shape after embedding at timestep 268: torch.Size([64, 1, 24])
# Shape after embedding at timestep 269: torch.Size([64, 1, 24])
# Shape after embedding at timestep 270: torch.Size([64, 1, 24])
# Shape after embedding at timestep 271: torch.Size([64, 1, 24])
# Shape after embedding at timestep 272: torch.Size([64, 1, 24])
# Shape after embedding at timestep 273: torch.Size([64, 1, 24])
# Shape after embedding at timestep 274: torch.Size([64, 1, 24])
# Shape after embedding at timestep 275: torch.Size([64, 1, 24])
# Shape after embedding at timestep 276: torch.Size([64, 1, 24])
# Shape after embedding at timestep 277: torch.Size([64, 1, 24])
# Shape after embedding at timestep 278: torch.Size([64, 1, 24])
# Shape after embedding at timestep 279: torch.Size([64, 1, 24])
# Shape after embedding at timestep 280: torch.Size([64, 1, 24])
# Shape after embedding at timestep 281: torch.Size([64, 1, 24])
# Shape after embedding at timestep 282: torch.Size([64, 1, 24])
# Shape after embedding at timestep 283: torch.Size([64, 1, 24])
# Shape after embedding at timestep 284: torch.Size([64, 1, 24])
# Shape after embedding at timestep 285: torch.Size([64, 1, 24])
# Shape after embedding at timestep 286: torch.Size([64, 1, 24])
# Shape after embedding at timestep 287: torch.Size([64, 1, 24])
# Shape after embedding at timestep 288: torch.Size([64, 1, 24])
# Shape after embedding at timestep 289: torch.Size([64, 1, 24])
# Shape after embedding at timestep 290: torch.Size([64, 1, 24])
# Shape after embedding at timestep 291: torch.Size([64, 1, 24])
# Shape after embedding at timestep 292: torch.Size([64, 1, 24])
# Shape after embedding at timestep 293: torch.Size([64, 1, 24])
# Shape after embedding at timestep 294: torch.Size([64, 1, 24])
# Shape after embedding at timestep 295: torch.Size([64, 1, 24])
# Shape after embedding at timestep 296: torch.Size([64, 1, 24])
# Shape after embedding at timestep 297: torch.Size([64, 1, 24])
# Shape after embedding at timestep 298: torch.Size([64, 1, 24])
# Shape after embedding at timestep 299: torch.Size([64, 1, 24])
# Shape after embedding at timestep 300: torch.Size([64, 1, 24])
# Shape after embedding at timestep 301: torch.Size([64, 1, 24])
# Shape after embedding at timestep 302: torch.Size([64, 1, 24])
# Shape after embedding at timestep 303: torch.Size([64, 1, 24])
# Shape after embedding at timestep 304: torch.Size([64, 1, 24])
# Shape after embedding at timestep 305: torch.Size([64, 1, 24])
# Shape after embedding at timestep 306: torch.Size([64, 1, 24])
# Shape after embedding at timestep 307: torch.Size([64, 1, 24])
# Shape after embedding at timestep 308: torch.Size([64, 1, 24])
# Shape after embedding at timestep 309: torch.Size([64, 1, 24])
# Shape after embedding at timestep 310: torch.Size([64, 1, 24])
# Shape after embedding at timestep 311: torch.Size([64, 1, 24])
# Shape after embedding at timestep 312: torch.Size([64, 1, 24])
# Shape after embedding at timestep 313: torch.Size([64, 1, 24])
# Shape after embedding at timestep 314: torch.Size([64, 1, 24])
# Shape after embedding at timestep 315: torch.Size([64, 1, 24])
# Shape after embedding at timestep 316: torch.Size([64, 1, 24])
# Shape after embedding at timestep 317: torch.Size([64, 1, 24])
# Shape after embedding at timestep 318: torch.Size([64, 1, 24])
# Shape after embedding at timestep 319: torch.Size([64, 1, 24])
# Shape after embedding at timestep 320: torch.Size([64, 1, 24])
# Shape after embedding at timestep 321: torch.Size([64, 1, 24])
# Shape after embedding at timestep 322: torch.Size([64, 1, 24])
# Shape after embedding at timestep 323: torch.Size([64, 1, 24])
# Shape after embedding at timestep 324: torch.Size([64, 1, 24])
# Shape after embedding at timestep 325: torch.Size([64, 1, 24])
# Shape after embedding at timestep 326: torch.Size([64, 1, 24])
# Shape after embedding at timestep 327: torch.Size([64, 1, 24])
# Shape after embedding at timestep 328: torch.Size([64, 1, 24])
# Shape after embedding at timestep 329: torch.Size([64, 1, 24])
# Shape after embedding at timestep 330: torch.Size([64, 1, 24])
# Shape after embedding at timestep 331: torch.Size([64, 1, 24])
# Shape after embedding at timestep 332: torch.Size([64, 1, 24])
# Shape after embedding at timestep 333: torch.Size([64, 1, 24])
# Shape after embedding at timestep 334: torch.Size([64, 1, 24])
# Shape after embedding at timestep 335: torch.Size([64, 1, 24])
# Shape after embedding at timestep 336: torch.Size([64, 1, 24])
# Shape after embedding at timestep 337: torch.Size([64, 1, 24])
# Shape after embedding at timestep 338: torch.Size([64, 1, 24])
# Shape after embedding at timestep 339: torch.Size([64, 1, 24])
# Shape after embedding at timestep 340: torch.Size([64, 1, 24])
# Shape after embedding at timestep 341: torch.Size([64, 1, 24])
# Shape after embedding at timestep 342: torch.Size([64, 1, 24])
# Shape after embedding at timestep 343: torch.Size([64, 1, 24])
# Shape after embedding at timestep 344: torch.Size([64, 1, 24])
# Shape after embedding at timestep 345: torch.Size([64, 1, 24])
# Shape after embedding at timestep 346: torch.Size([64, 1, 24])
# Shape after embedding at timestep 347: torch.Size([64, 1, 24])
# Shape after embedding at timestep 348: torch.Size([64, 1, 24])
# Shape after embedding at timestep 349: torch.Size([64, 1, 24])
# Shape after embedding at timestep 350: torch.Size([64, 1, 24])
# Shape after embedding at timestep 351: torch.Size([64, 1, 24])
# Shape after embedding at timestep 352: torch.Size([64, 1, 24])
# Shape after embedding at timestep 353: torch.Size([64, 1, 24])
# Shape after embedding at timestep 354: torch.Size([64, 1, 24])
# Shape after embedding at timestep 355: torch.Size([64, 1, 24])
# Shape after embedding at timestep 356: torch.Size([64, 1, 24])
# Shape after embedding at timestep 357: torch.Size([64, 1, 24])
# Shape after embedding at timestep 358: torch.Size([64, 1, 24])
# Shape after embedding at timestep 359: torch.Size([64, 1, 24])
# ...
# Shape after embedding at timestep 253: torch.Size([64, 1, 24])
# Shape after embedding at timestep 254: torch.Size([64, 1, 24])
# Shape after embedding at timestep 255: torch.Size([64, 1, 24])
# Shape after embedding at timestep 256: torch.Size([64, 1, 24])
# Shape after embedding at timestep 257: torch.Size([64, 1, 24])
# Shape after embedding at timestep 258: torch.Size([64, 1, 24])
# Shape after embedding at timestep 259: torch.Size([64, 1, 24])
# Shape after embedding at timestep 260: torch.Size([64, 1, 24])
# Shape after embedding at timestep 261: torch.Size([64, 1, 24])
# Shape after embedding at timestep 262: torch.Size([64, 1, 24])
# Shape after embedding at timestep 263: torch.Size([64, 1, 24])
# Shape after embedding at timestep 264: torch.Size([64, 1, 24])
# Shape after embedding at timestep 265: torch.Size([64, 1, 24])
# Shape after embedding at timestep 266: torch.Size([64, 1, 24])
# Shape after embedding at timestep 267: torch.Size([64, 1, 24])
# Shape after embedding at timestep 268: torch.Size([64, 1, 24])
# Shape after embedding at timestep 269: torch.Size([64, 1, 24])
# Shape after embedding at timestep 270: torch.Size([64, 1, 24])
# Shape after embedding at timestep 271: torch.Size([64, 1, 24])
# Shape after embedding at timestep 272: torch.Size([64, 1, 24])
# Shape after embedding at timestep 273: torch.Size([64, 1, 24])
# Shape after embedding at timestep 274: torch.Size([64, 1, 24])
# Shape after embedding at timestep 275: torch.Size([64, 1, 24])
# Shape after embedding at timestep 276: torch.Size([64, 1, 24])
# Shape after embedding at timestep 277: torch.Size([64, 1, 24])
# Shape after embedding at timestep 278: torch.Size([64, 1, 24])
# Shape after embedding at timestep 279: torch.Size([64, 1, 24])
# Shape after embedding at timestep 280: torch.Size([64, 1, 24])
# Shape after embedding at timestep 281: torch.Size([64, 1, 24])
# Shape after embedding at timestep 282: torch.Size([64, 1, 24])
# Shape after embedding at timestep 283: torch.Size([64, 1, 24])
# Shape after embedding at timestep 284: torch.Size([64, 1, 24])
# Shape after embedding at timestep 285: torch.Size([64, 1, 24])
# Shape after embedding at timestep 286: torch.Size([64, 1, 24])
# Shape after embedding at timestep 287: torch.Size([64, 1, 24])
# Shape after embedding at timestep 288: torch.Size([64, 1, 24])
# Shape after embedding at timestep 289: torch.Size([64, 1, 24])
# Shape after embedding at timestep 290: torch.Size([64, 1, 24])
# Shape after embedding at timestep 291: torch.Size([64, 1, 24])
# Shape after embedding at timestep 292: torch.Size([64, 1, 24])
# Shape after embedding at timestep 293: torch.Size([64, 1, 24])
# Shape after embedding at timestep 294: torch.Size([64, 1, 24])
# Shape after embedding at timestep 295: torch.Size([64, 1, 24])
# Shape after embedding at timestep 296: torch.Size([64, 1, 24])
# Shape after embedding at timestep 297: torch.Size([64, 1, 24])
# Shape after embedding at timestep 298: torch.Size([64, 1, 24])
# Shape after embedding at timestep 299: torch.Size([64, 1, 24])
# Shape after embedding at timestep 300: torch.Size([64, 1, 24])
# Shape after embedding at timestep 301: torch.Size([64, 1, 24])
# Shape after embedding at timestep 302: torch.Size([64, 1, 24])
# Shape after embedding at timestep 303: torch.Size([64, 1, 24])
# Shape after embedding at timestep 304: torch.Size([64, 1, 24])
# Shape after embedding at timestep 305: torch.Size([64, 1, 24])
# Shape after embedding at timestep 306: torch.Size([64, 1, 24])
# Shape after embedding at timestep 307: torch.Size([64, 1, 24])
# Shape after embedding at timestep 308: torch.Size([64, 1, 24])
# Shape after embedding at timestep 309: torch.Size([64, 1, 24])
# Shape after embedding at timestep 310: torch.Size([64, 1, 24])
# Shape after embedding at timestep 311: torch.Size([64, 1, 24])
# Shape after embedding at timestep 312: torch.Size([64, 1, 24])
# Shape after embedding at timestep 313: torch.Size([64, 1, 24])
# Shape after embedding at timestep 314: torch.Size([64, 1, 24])
# Shape after embedding at timestep 315: torch.Size([64, 1, 24])
# Shape after embedding at timestep 316: torch.Size([64, 1, 24])
# Shape after embedding at timestep 317: torch.Size([64, 1, 24])
# Shape after embedding at timestep 318: torch.Size([64, 1, 24])
# Shape after embedding at timestep 319: torch.Size([64, 1, 24])
# Shape after embedding at timestep 320: torch.Size([64, 1, 24])
# Shape after embedding at timestep 321: torch.Size([64, 1, 24])
# Shape after embedding at timestep 322: torch.Size([64, 1, 24])
# Shape after embedding at timestep 323: torch.Size([64, 1, 24])
# Shape after embedding at timestep 324: torch.Size([64, 1, 24])
# Shape after embedding at timestep 325: torch.Size([64, 1, 24])
# Shape after embedding at timestep 326: torch.Size([64, 1, 24])
# Shape after embedding at timestep 327: torch.Size([64, 1, 24])
# Shape after embedding at timestep 328: torch.Size([64, 1, 24])
# Shape after embedding at timestep 329: torch.Size([64, 1, 24])
# Shape after embedding at timestep 330: torch.Size([64, 1, 24])
# Shape after embedding at timestep 331: torch.Size([64, 1, 24])
# Shape after embedding at timestep 332: torch.Size([64, 1, 24])
# Shape after embedding at timestep 333: torch.Size([64, 1, 24])
# Shape after embedding at timestep 334: torch.Size([64, 1, 24])
# Shape after embedding at timestep 335: torch.Size([64, 1, 24])
# Shape after embedding at timestep 336: torch.Size([64, 1, 24])
# Shape after embedding at timestep 337: torch.Size([64, 1, 24])
# Shape after embedding at timestep 338: torch.Size([64, 1, 24])
# Shape after embedding at timestep 339: torch.Size([64, 1, 24])
# Shape after embedding at timestep 340: torch.Size([64, 1, 24])
# Shape after embedding at timestep 341: torch.Size([64, 1, 24])
# Shape after embedding at timestep 342: torch.Size([64, 1, 24])
# Shape after embedding at timestep 343: torch.Size([64, 1, 24])
# Shape after embedding at timestep 344: torch.Size([64, 1, 24])
# Shape after embedding at timestep 345: torch.Size([64, 1, 24])
# Shape after embedding at timestep 346: torch.Size([64, 1, 24])
# Shape after embedding at timestep 347: torch.Size([64, 1, 24])
# Shape after embedding at timestep 348: torch.Size([64, 1, 24])
# Shape after embedding at timestep 349: torch.Size([64, 1, 24])
# Shape after embedding at timestep 350: torch.Size([64, 1, 24])
# Shape after embedding at timestep 351: torch.Size([64, 1, 24])
# Shape after embedding at timestep 352: torch.Size([64, 1, 24])
# Shape after embedding at timestep 353: torch.Size([64, 1, 24])
# Shape after embedding at timestep 354: torch.Size([64, 1, 24])
# Shape after embedding at timestep 355: torch.Size([64, 1, 24])
# Shape after embedding at timestep 356: torch.Size([64, 1, 24])
# Shape after embedding at timestep 357: torch.Size([64, 1, 24])
# Shape after embedding at timestep 358: torch.Size([64, 1, 24])
# Shape after embedding at timestep 359: torch.Size([64, 1, 24])
# Shape after embedding at timestep 360: torch.Size([64, 1, 24])
# Shape after embedding at timestep 361: torch.Size([64, 1, 24])
# Shape after embedding at timestep 362: torch.Size([64, 1, 24])
# Shape after embedding at timestep 363: torch.Size([64, 1, 24])
# Shape after embedding at timestep 364: torch.Size([64, 1, 24])
# Shape after embedding at timestep 365: torch.Size([64, 1, 24])
# Shape after embedding at timestep 366: torch.Size([64, 1, 24])
# Shape after embedding at timestep 367: torch.Size([64, 1, 24])
# Shape after embedding at timestep 368: torch.Size([64, 1, 24])
# Shape after embedding at timestep 369: torch.Size([64, 1, 24])
# Shape after embedding at timestep 370: torch.Size([64, 1, 24])
# Shape after embedding at timestep 371: torch.Size([64, 1, 24])
# Shape after embedding at timestep 372: torch.Size([64, 1, 24])
# Shape after embedding at timestep 373: torch.Size([64, 1, 24])
# Shape after embedding at timestep 374: torch.Size([64, 1, 24])
# Shape after embedding at timestep 375: torch.Size([64, 1, 24])
# Shape after embedding at timestep 376: torch.Size([64, 1, 24])
# Shape after embedding at timestep 377: torch.Size([64, 1, 24])
# Shape after embedding at timestep 378: torch.Size([64, 1, 24])
# Shape after embedding at timestep 379: torch.Size([64, 1, 24])
# Shape after embedding at timestep 380: torch.Size([64, 1, 24])
# Shape after embedding at timestep 381: torch.Size([64, 1, 24])
# Shape after embedding at timestep 382: torch.Size([64, 1, 24])
# Shape after embedding at timestep 383: torch.Size([64, 1, 24])
# Shape after embedding at timestep 384: torch.Size([64, 1, 24])
# Shape after embedding at timestep 385: torch.Size([64, 1, 24])
# Shape after embedding at timestep 386: torch.Size([64, 1, 24])
# Shape after embedding at timestep 387: torch.Size([64, 1, 24])
# Shape after embedding at timestep 388: torch.Size([64, 1, 24])
# Shape after embedding at timestep 389: torch.Size([64, 1, 24])
# Shape after embedding at timestep 390: torch.Size([64, 1, 24])
# Shape after embedding at timestep 391: torch.Size([64, 1, 24])
# Shape after embedding at timestep 392: torch.Size([64, 1, 24])
# Shape after embedding at timestep 393: torch.Size([64, 1, 24])
# Shape after embedding at timestep 394: torch.Size([64, 1, 24])
# Shape after embedding at timestep 395: torch.Size([64, 1, 24])
# Shape after embedding at timestep 396: torch.Size([64, 1, 24])
# Shape after embedding at timestep 397: torch.Size([64, 1, 24])
# Shape after embedding at timestep 398: torch.Size([64, 1, 24])
# Shape after embedding at timestep 399: torch.Size([64, 1, 24])
# Encoder output shape: torch.Size([64, 400, 24])
# Initial dec_input shape: torch.Size([64, 1, 1])
# Shape after embedding at timestep 0: torch.Size([64, 1, 24])
# Shape after embedding at timestep 1: torch.Size([64, 1, 24])
# Shape after embedding at timestep 2: torch.Size([64, 1, 24])
# Shape after embedding at timestep 3: torch.Size([64, 1, 24])
# Shape after embedding at timestep 4: torch.Size([64, 1, 24])
# Shape after embedding at timestep 5: torch.Size([64, 1, 24])
# Shape after embedding at timestep 6: torch.Size([64, 1, 24])
# Shape after embedding at timestep 7: torch.Size([64, 1, 24])
# Shape after embedding at timestep 8: torch.Size([64, 1, 24])
# Shape after embedding at timestep 9: torch.Size([64, 1, 24])
# Shape after embedding at timestep 10: torch.Size([64, 1, 24])
# Shape after embedding at timestep 11: torch.Size([64, 1, 24])
# Shape after embedding at timestep 12: torch.Size([64, 1, 24])
# Shape after embedding at timestep 13: torch.Size([64, 1, 24])
# Shape after embedding at timestep 14: torch.Size([64, 1, 24])
# Shape after embedding at timestep 15: torch.Size([64, 1, 24])
# Shape after embedding at timestep 16: torch.Size([64, 1, 24])
# Shape after embedding at timestep 17: torch.Size([64, 1, 24])
# Shape after embedding at timestep 18: torch.Size([64, 1, 24])
# Shape after embedding at timestep 19: torch.Size([64, 1, 24])
# Shape after embedding at timestep 20: torch.Size([64, 1, 24])
# Shape after embedding at timestep 21: torch.Size([64, 1, 24])
# Shape after embedding at timestep 22: torch.Size([64, 1, 24])
# Shape after embedding at timestep 23: torch.Size([64, 1, 24])
# Shape after embedding at timestep 24: torch.Size([64, 1, 24])
# Shape after embedding at timestep 25: torch.Size([64, 1, 24])
# Shape after embedding at timestep 26: torch.Size([64, 1, 24])
# Shape after embedding at timestep 27: torch.Size([64, 1, 24])
# Shape after embedding at timestep 28: torch.Size([64, 1, 24])
# Shape after embedding at timestep 29: torch.Size([64, 1, 24])
# Shape after embedding at timestep 30: torch.Size([64, 1, 24])
# Shape after embedding at timestep 31: torch.Size([64, 1, 24])
# Shape after embedding at timestep 32: torch.Size([64, 1, 24])
# Shape after embedding at timestep 33: torch.Size([64, 1, 24])
# Shape after embedding at timestep 34: torch.Size([64, 1, 24])
# Shape after embedding at timestep 35: torch.Size([64, 1, 24])
# Shape after embedding at timestep 36: torch.Size([64, 1, 24])
# Shape after embedding at timestep 37: torch.Size([64, 1, 24])
# Shape after embedding at timestep 38: torch.Size([64, 1, 24])
# Shape after embedding at timestep 39: torch.Size([64, 1, 24])
# Shape after embedding at timestep 40: torch.Size([64, 1, 24])
# Shape after embedding at timestep 41: torch.Size([64, 1, 24])
# Shape after embedding at timestep 42: torch.Size([64, 1, 24])
# Shape after embedding at timestep 43: torch.Size([64, 1, 24])
# Shape after embedding at timestep 44: torch.Size([64, 1, 24])
# Shape after embedding at timestep 45: torch.Size([64, 1, 24])
# Shape after embedding at timestep 46: torch.Size([64, 1, 24])
# Shape after embedding at timestep 47: torch.Size([64, 1, 24])
# Shape after embedding at timestep 48: torch.Size([64, 1, 24])
# Shape after embedding at timestep 49: torch.Size([64, 1, 24])
# Shape after embedding at timestep 50: torch.Size([64, 1, 24])
# Shape after embedding at timestep 51: torch.Size([64, 1, 24])
# Shape after embedding at timestep 52: torch.Size([64, 1, 24])
# Shape after embedding at timestep 53: torch.Size([64, 1, 24])
# Shape after embedding at timestep 54: torch.Size([64, 1, 24])
# Shape after embedding at timestep 55: torch.Size([64, 1, 24])
# Shape after embedding at timestep 56: torch.Size([64, 1, 24])
# Shape after embedding at timestep 57: torch.Size([64, 1, 24])
# Shape after embedding at timestep 58: torch.Size([64, 1, 24])
# Shape after embedding at timestep 59: torch.Size([64, 1, 24])
# Shape after embedding at timestep 60: torch.Size([64, 1, 24])
# Shape after embedding at timestep 61: torch.Size([64, 1, 24])
# Shape after embedding at timestep 62: torch.Size([64, 1, 24])
# Shape after embedding at timestep 63: torch.Size([64, 1, 24])
# Shape after embedding at timestep 64: torch.Size([64, 1, 24])
# Shape after embedding at timestep 65: torch.Size([64, 1, 24])
# Shape after embedding at timestep 66: torch.Size([64, 1, 24])
# Shape after embedding at timestep 67: torch.Size([64, 1, 24])
# Shape after embedding at timestep 68: torch.Size([64, 1, 24])
# Shape after embedding at timestep 69: torch.Size([64, 1, 24])
# Shape after embedding at timestep 70: torch.Size([64, 1, 24])
# Shape after embedding at timestep 71: torch.Size([64, 1, 24])
# Shape after embedding at timestep 72: torch.Size([64, 1, 24])
# Shape after embedding at timestep 73: torch.Size([64, 1, 24])
# Shape after embedding at timestep 74: torch.Size([64, 1, 24])
# Shape after embedding at timestep 75: torch.Size([64, 1, 24])
# Shape after embedding at timestep 76: torch.Size([64, 1, 24])
# Shape after embedding at timestep 77: torch.Size([64, 1, 24])
# Shape after embedding at timestep 78: torch.Size([64, 1, 24])
# Shape after embedding at timestep 79: torch.Size([64, 1, 24])
# Shape after embedding at timestep 80: torch.Size([64, 1, 24])
# Shape after embedding at timestep 81: torch.Size([64, 1, 24])
# Shape after embedding at timestep 82: torch.Size([64, 1, 24])
# Shape after embedding at timestep 83: torch.Size([64, 1, 24])
# Shape after embedding at timestep 84: torch.Size([64, 1, 24])
# Shape after embedding at timestep 85: torch.Size([64, 1, 24])
# Shape after embedding at timestep 86: torch.Size([64, 1, 24])
# Shape after embedding at timestep 87: torch.Size([64, 1, 24])
# Shape after embedding at timestep 88: torch.Size([64, 1, 24])
# Shape after embedding at timestep 89: torch.Size([64, 1, 24])
# Shape after embedding at timestep 90: torch.Size([64, 1, 24])
# Shape after embedding at timestep 91: torch.Size([64, 1, 24])
# Shape after embedding at timestep 92: torch.Size([64, 1, 24])
# Shape after embedding at timestep 93: torch.Size([64, 1, 24])
# Shape after embedding at timestep 94: torch.Size([64, 1, 24])
# Shape after embedding at timestep 95: torch.Size([64, 1, 24])
# Shape after embedding at timestep 96: torch.Size([64, 1, 24])
# Shape after embedding at timestep 97: torch.Size([64, 1, 24])
# Shape after embedding at timestep 98: torch.Size([64, 1, 24])
# Shape after embedding at timestep 99: torch.Size([64, 1, 24])
# Shape after embedding at timestep 100: torch.Size([64, 1, 24])
# Shape after embedding at timestep 101: torch.Size([64, 1, 24])
# Shape after embedding at timestep 102: torch.Size([64, 1, 24])
# Shape after embedding at timestep 103: torch.Size([64, 1, 24])
# Shape after embedding at timestep 104: torch.Size([64, 1, 24])
# Shape after embedding at timestep 105: torch.Size([64, 1, 24])
# Shape after embedding at timestep 106: torch.Size([64, 1, 24])
